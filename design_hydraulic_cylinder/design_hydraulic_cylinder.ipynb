# %%
import pygad

# %%
# Função 
# Restrições

# %%
# gerar input (array) aleatório

# %%
import pygad
import numpy

"""
Given the following function:
    y = f(w1:w6) = w1x1 + w2x2 + w3x3 + w4x4 + w5x5 + 6wx6
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11,-4.7) and y=44
What are the best values for the 6 weights (w1 to w6)? We are going to use the genetic algorithm to optimize this function.
"""

function_inputs = [4,-2,3.5,5,-11,-4.7] # Function inputs.
desired_output = 44 # Function output.

def fitness_func(solution, solution_idx):
    # Calculating the fitness value of each solution in the current population.
    # The fitness function calulates the sum of products between each input and its corresponding weight.
    x = solution*function_inputs




    
    output = numpy.sum(x)
    fitness = 1.0 / numpy.abs(output - desired_output)
    return fitness

fitness_function = fitness_func

num_generations = 100 # Number of generations.
num_parents_mating = 7 # Number of solutions to be selected as parents in the mating pool.

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter. This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters. If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
sol_per_pop = 50 # Number of solutions in the population.
num_genes = len(function_inputs)

last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       on_generation=callback_generation)

# Running the GA to optimize the parameters of the function.
ga_instance.run()

# After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
ga_instance.plot_fitness()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

prediction = numpy.sum(numpy.array(function_inputs)*solution)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# Saving the GA instance.
filename = 'genetic' # The filename to which the instance is saved. The name is without extension.
ga_instance.save(filename=filename)

# Loading the saved GA instance.
loaded_ga_instance = pygad.load(filename=filename)
loaded_ga_instance.plot_fitness()
# Out:
# Generation = 1
# Fitness    = 1.393768337752126
# Change     = 1.393768337752126
# Generation = 2
# Fitness    = 66.0005447975401
# Change     = 64.60677645978798
# Generation = 3
# Fitness    = 66.0005447975401
# Change     = 0.0
# Generation = 4
# Fitness    = 66.0005447975401
# Change     = 0.0
# Generation = 5
# Fitness    = 66.0005447975401
# Change     = 0.0
# Generation = 6
# Fitness    = 601.1783526067112
# Change     = 535.1778078091711
# Generation = 7
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 8
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 9
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 10
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 11
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 12
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 13
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 14
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 15
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 16
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 17
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 18
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 19
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 20
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 21
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 22
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 23
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 24
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 25
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 26
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 27
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 28
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 29
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 30
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 31
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 32
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 33
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 34
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 35
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 36
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 37
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 38
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 39
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 40
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 41
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 42
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 43
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 44
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 45
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 46
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 47
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 48
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 49
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 50
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 51
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 52
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 53
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 54
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 55
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 56
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 57
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 58
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 59
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 60
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 61
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 62
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 63
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 64
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 65
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 66
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 67
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 68
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 69
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 70
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 71
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 72
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 73
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 74
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 75
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 76
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 77
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 78
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 79
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 80
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 81
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 82
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 83
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 84
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 85
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 86
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 87
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 88
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 89
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 90
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 91
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 92
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 93
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 94
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 95
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 96
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 97
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 98
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 99
# Fitness    = 601.1783526067112
# Change     = 0.0
# Generation = 100
# Fitness    = 601.1783526067112
# Change     = 0.0
# Parameters of the best solution : [ 1.78365227 -1.35171516  3.10743458 -0.16051679 -2.85558398  1.55841781]
# Fitness value of the best solution = 601.1783526067112
# Index of the best solution : 0
# Predicted output based on the best solution : 43.99833660011931
# Best fitness value reached after 6 generations.
